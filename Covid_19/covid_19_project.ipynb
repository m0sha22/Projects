# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('owid-covid-data.csv')

# %%
# exploring the data

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259209 entries, 0 to 259208
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    259209 non-null  object
#  1   continent                                   244664 non-null  object
#  2   location                                    259209 non-null  object
#  3   date                                        259209 non-null  object
#  4   total_cases                                 244641 non-null  float64
#  5   new_cases                                   244357 non-null  float64
#  6   new_cases_smoothed                          243153 non-null  float64
#  7   total_deaths                                224960 non-null  float64
#  8   new_deaths                                  224858 non-null  float64
# ...

# %%
df.shape
# Out:
# (259209, 67)

# %% [markdown]
# # # Exploring data

# %%
#Listing all countries / regions in our data
df['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
# how many countries / regions in our data
df['location'].nunique()
# Out:
# 248

# %% [markdown]
# # Exploring the World data

# %%
#Selecting the world data
world_df = df[df['location'] == 'World']
world_df
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 254894  OWID_WRL       NaN    World  2020-01-22        557.0        0.0
# 254895  OWID_WRL       NaN    World  2020-01-23        657.0      100.0
# 254896  OWID_WRL       NaN    World  2020-01-24        944.0      287.0
# 254897  OWID_WRL       NaN    World  2020-01-25       1437.0      493.0
# 254898  OWID_WRL       NaN    World  2020-01-26       2120.0      683.0
# ...          ...       ...      ...         ...          ...        ...
# 256016  OWID_WRL       NaN    World  2023-02-17  673765471.0   193950.0
# 256017  OWID_WRL       NaN    World  2023-02-18  673855803.0    90332.0
# 256018  OWID_WRL       NaN    World  2023-02-19  673941526.0    85723.0
# 256019  OWID_WRL       NaN    World  2023-02-20  674027446.0    85920.0
# 256020  OWID_WRL       NaN    World  2023-02-21  674190824.0   163378.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
# Finding the date of the maximum number of deaths all over the world
world_df[world_df.total_deaths == world_df['total_deaths'].max()]['date']
# Out:
# 256020    2023-02-21
# Name: date, dtype: object

# %%
#Creating a summary table for the most recent date all over the world
world_recent = world_df[world_df.date == world_df['date'].max()]
world_recent.groupby(['date'])[["total_cases","new_cases","new_deaths","total_deaths"]].sum()
# Out:
#             total_cases  new_cases  new_deaths  total_deaths
# date
# 2023-02-21  674190824.0   163378.0       682.0     6864099.0

# %%
world_df['population'].max()
# Out:
# 7975105024.0

# %%
world_df['total_cases'].max()
# Out:
# 674190824.0

# %%
# Calculating the percentage of confirmed cases regarding the world populati\on
percentage = (world_df['total_cases'].max() / world_df['population'].max())
percentage
# Out:
# 0.0845369210776678

# %% [markdown]
# ==============

# %% [markdown]
# # VISUALLIZING WORLD DATA

# %% [markdown]
# ## Confirmed cases (Total Cases) all over the world

# %%
df_world_over_time= world_df.groupby(['date'])[["total_cases","new_cases","total_deaths","new_deaths"]].sum().reset_index()
df_world_over_time.date = pd.to_datetime(df_world_over_time.date)
df_world_over_time.set_index('date', inplace=True)
df_world_over_time.total_cases
# Out:
# date
# 2020-01-22          557.0
# 2020-01-23          657.0
# 2020-01-24          944.0
# 2020-01-25         1437.0
# 2020-01-26         2120.0
#                  ...
# 2023-02-17    673765471.0
# 2023-02-18    673855803.0
# 2023-02-19    673941526.0
# 2023-02-20    674027446.0
# 2023-02-21    674190824.0
# Name: total_cases, Length: 1127, dtype: float64

# %%
# Using line-plot
plt.figure(figsize=(20,10))
plt.plot(df_world_over_time.index, df_world_over_time.total_cases)
plt.title('Evolution of Confirmed Covid-19 cases over time in the word', fontsize=16)
plt.xlabel('Days', fontsize=16)
plt.ylabel('Confirmed cases', fontsize=16)
plt.show()

# %%
#Total deaths cases evolution over time
# Using line-plot
plt.figure(figsize=(20,10))
plt.plot(df_world_over_time.index, df_world_over_time['total_deaths'])
plt.title('Evolution of Covid-19 Deaths cases over time in the world', fontsize=16)
plt.xlabel('Days', fontsize=16)
plt.ylabel('Number of Deaths', fontsize=16)
# Out:
# Text(0, 0.5, 'Number of Deaths')

# %%
# new cases evolution over time
# Using line-plot
plt.figure(figsize=(20,10))
plt.plot(df_world_over_time.index, df_world_over_time['new_cases'])
plt.title('Evolution of Covid-19 New cases over time in the world', fontsize=16)
plt.xlabel('Days', fontsize=16)
plt.ylabel('Number of New Cases', fontsize=16)
# Out:
# Text(0, 0.5, 'Number of New Cases')

# %%
# Using line-plot
plt.figure(figsize=(20,10))
plt.plot(df_world_over_time.index, df_world_over_time['total_cases'], label='Confirmed')
plt.plot(df_world_over_time.index, df_world_over_time['total_deaths'], label='Total Deaths')
plt.plot(df_world_over_time.index, df_world_over_time['new_cases'], label='New')
plt.plot(df_world_over_time.index, df_world_over_time['new_deaths'], label='New Deaths')
plt.legend(loc=0)
plt.show()

# %% [markdown]
# ========

# %% [markdown]
# # Exploring the USA data

# %%
usa_df_total = df[df['location'] == 'United States']
dict(usa_df_total.isna().sum())
# Out:
# {'iso_code': 0,
#  'continent': 0,
#  'location': 0,
#  'date': 0,
#  'total_cases': 0,
#  'new_cases': 1,
#  'new_cases_smoothed': 6,
#  'total_deaths': 38,
#  'new_deaths': 40,
#  'new_deaths_smoothed': 45,
#  'total_cases_per_million': 0,
#  'new_cases_per_million': 1,
#  'new_cases_smoothed_per_million': 6,
#  'total_deaths_per_million': 38,
#  'new_deaths_per_million': 40,
#  'new_deaths_smoothed_per_million': 45,
#  'reproduction_rate': 93,
#  'icu_patients': 177,
#  'icu_patients_per_million': 177,
#  'hosp_patients': 177,
#  'hosp_patients_per_million': 177,
#  'weekly_icu_admissions': 1127,
#  'weekly_icu_admissions_per_million': 1127,
#  'weekly_hosp_admissions': 183,
#  'weekly_hosp_admissions_per_million': 183,
#  'total_tests': 287,
#  'new_tests': 287,
#  'total_tests_per_thousand': 287,
#  'new_tests_per_thousand': 287,
#  'new_tests_smoothed': 294,
#  'new_tests_smoothed_per_thousand': 294,
#  'positive_rate': 293,
#  'tests_per_case': 293,
#  'tests_units': 287,
# ...

# %%
usa_df = usa_df_total[['date','total_cases', 'new_cases', 'total_deaths', 'new_deaths','female_smokers','male_smokers','median_age']]
usa_df.head()
# Out:
#               date  total_cases  new_cases  total_deaths  new_deaths  \
# 243644  2020-01-22          1.0        NaN           NaN         NaN
# 243645  2020-01-23          1.0        0.0           NaN         NaN
# 243646  2020-01-24          2.0        1.0           NaN         NaN
# 243647  2020-01-25          2.0        0.0           NaN         NaN
# 243648  2020-01-26          5.0        3.0           NaN         NaN
#
#         female_smokers  male_smokers  median_age
# 243644            19.1          24.6        38.3
# 243645            19.1          24.6        38.3
# 243646            19.1          24.6        38.3
# 243647            19.1          24.6        38.3
# 243648            19.1          24.6        38.3

# %%
usa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1127 entries, 243644 to 244770
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            1127 non-null   object
#  1   total_cases     1127 non-null   float64
#  2   new_cases       1126 non-null   float64
#  3   total_deaths    1089 non-null   float64
#  4   new_deaths      1087 non-null   float64
#  5   female_smokers  1127 non-null   float64
#  6   male_smokers    1127 non-null   float64
#  7   median_age      1127 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 79.2+ KB

# %%
# fillling nan values
usa_df['new_cases'].fillna(method = "bfill", inplace=True)
usa_df['total_deaths'].fillna(method ='bfill', inplace=True)
usa_df['total_cases'].fillna(method = "bfill", inplace=True)
usa_df['new_deaths'].fillna(method = 'bfill', inplace=True)
usa_df['female_smokers'].fillna(method = 'bfill', inplace=True)
usa_df['male_smokers'].fillna(method = 'bfill', inplace=True)
usa_df['date'].fillna(method = 'bfill', inplace=True)

# %%
# Convert date to datetime
pd.to_datetime(usa_df.date)
# Out:
# 243644   2020-01-22
# 243645   2020-01-23
# 243646   2020-01-24
# 243647   2020-01-25
# 243648   2020-01-26
#             ...
# 244766   2023-02-17
# 244767   2023-02-18
# 244768   2023-02-19
# 244769   2023-02-20
# 244770   2023-02-21
# Name: date, Length: 1127, dtype: datetime64[ns]

# %%
# set the index to the date
usa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1127 entries, 243644 to 244770
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            1127 non-null   datetime64[ns]
#  1   total_cases     1127 non-null   float64
#  2   new_cases       1127 non-null   float64
#  3   total_deaths    1127 non-null   float64
#  4   new_deaths      1127 non-null   float64
#  5   female_smokers  1127 non-null   float64
#  6   male_smokers    1127 non-null   float64
#  7   median_age      1127 non-null   float64
# dtypes: datetime64[ns](1), float64(7)
# memory usage: 79.2 KB

# %%
# seeing the recent values
usa_df[usa_df.date == usa_df.date.max()]
# Out:
#              date  total_cases  new_cases  total_deaths  new_deaths  \
# 244770 2023-02-21  103168534.0    43889.0     1117820.0       257.0
#
#         female_smokers  male_smokers  median_age
# 244770            19.1          24.6        38.3

# %%
#reset the index
usa_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Visualizing the data

# %%
plt.figure(figsize=(20,10))
plt.plot(usa_df.date, usa_df['new_cases'])
plt.xlabel('date')
plt.ylabel('New cases')
plt.title('USA New cases')
# Out:
# Text(0.5, 1.0, 'USA New cases')

# %%
# New cases in January 2021
jan_df_usa = usa_df[(usa_df['date'] >= '2021-01-01') & (usa_df['date'] < '2021-02-01')][['date', 'new_cases']]
plt.figure(figsize=(20,10))
plt.plot(jan_df_usa.date, jan_df_usa.new_cases)
plt.xlabel('January_2021')
plt.ylabel('New cases')
plt.title('USA New cases in January 2021')
# Out:
# Text(0.5, 1.0, 'USA New cases in January 2021')

# %%
# The highest number of the new cases
jan_df_usa[jan_df_usa.new_cases== jan_df_usa.new_cases.max()]
# Out:
#           date  new_cases
# 352 2021-01-08   302861.0
